# %% [markdown]
# # {Whatever} Usage Notes

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %%bash
#
# tree -d ./dev/
# Out:
# ./dev/
# ├── derivatives
# │   ├── first-level-output
# │   │   └── sub-01024
# │   │       └── task-faces
# │   │           ├── models
# │   │           │   ├── condition-maps
# │   │           │   └── contrast-maps
# │   │           └── plots
# │   │               ├── condition-maps
# │   │               └── contrast-maps
# │   └── fmriprep
# │       └── sub-01024
# │           ├── anat
# │           ├── figures
# │           ├── func
# │           └── log
# │               ├── 20210604-114844_8ed37dd2-a61e-4128-a0a3-5c0491e1f6fc
# │               ├── 20211111-145847_c78d18b6-bc77-40ca-9e6a-e98a9cdfb664
# │               └── 20211111-160932_dfbd1280-0845-45b7-a4d1-7a43fc101391
# └── sub-01024
#     ├── anat
#     ├── fmap
#     └── func
#
# 23 directories

# %%
import subject_level.bids_pointer as bids_pointer
import os

test = bids_pointer.BIDSPointer('01024', 'stressbuffer', './dev/', suppress=False)
# Out:
# {
#     "Subject ID": "01024",
#     "Task": "stressbuffer",
#     "# of Functional Runs": 3,
#     "Output Directory": "./dev/derivatives/first-level-output/sub-01024/task-stressbuffer",
#     "Defined Contrasts": "default"
# }

# %%
test.load_events(run=2)
# Out:
#     onset  duration  block_type  target                 image  \
# 0       2         5        self  s01024  ../images/s01024.jpg
# 1       7        10        self  s01024  ../images/s01024.jpg
# 2      17        30        self  s01024  ../images/s01024.jpg
# 3      47         5        self  s01024  ../images/s01024.jpg
# 4      52         5        self  s01024  ../images/s01024.jpg
# 5      57        15        self  s01024  ../images/s01024.jpg
# 6      72        10   low_trust  s01007  ../images/s01007.jpg
# 7      82        30   low_trust  s01007  ../images/s01007.jpg
# 8     112         5   low_trust  s01007  ../images/s01007.jpg
# 9     117         5   low_trust  s01007  ../images/s01007.jpg
# 10    122        15   low_trust  s01007  ../images/s01007.jpg
# 11    137        10  high_trust  s01008  ../images/s01008.jpg
# 12    147        30  high_trust  s01008  ../images/s01008.jpg
# 13    177         5  high_trust  s01008  ../images/s01008.jpg
# ...
